# %% [markdown]
# # DSGA1007 - Programming for Data Science Lab
# - Comprehensions (List, Dictionaries, Sets)
# - Lambda Functions
# - Functional Programming
# - Verify program correctness (some testing cases / assertions)

# %%
import numpy as np
import string
from numpy import random
from functools import reduce
from operator import add
from collections import Counter

# %% [markdown]
# # Let's get to work right away!
# ### <font color='blue'>Exercise 1 – Alphabet count</font>
# In this exercise you will implement a counter using the intuition of the MapReduce paradigm, which is inspired by the **map** and **reduce** functions from Functional Programming that you saw in Lecture.
#
# Follow the instructions in the code comments, when necessary.

# %%
alphabet = string.ascii_lowercase
original_count_letters = random.randint(1, 10, size=len(alphabet)) # This is the ground truth
random_letters = [alphabet[i] for i, count in enumerate(original_count_letters) for j in range(count)]

# %% [markdown]
# How long is the sequence of letters? Is this sequence always the same length? Why?

# %%
len(random_letters)
# Out:
# 134

# %% [markdown]
# Implement the assert_generation function as described by its docstring.
#
# The idea is to validate that we generated the data correctly.

# %%
def assert_generation(original_count_letters, alphabet, random_letters):
    """Make sure that the generation process is correct.

    There should be original_count_letters[i] elements for alphabet[i]
    symbol in the random_letters list.
    
    Args:
        original_count_letters (list): contains number of elements for each alphabet symbol
        alphabet (str): Alphabet string
        random_letters (list): generated ramdom letters
    
    Returns:
        bool: Assertion 
    """
    first = 0
    alphabet_length = len(alphabet)
    try:
        for i in range(alphabet_length):
            last = first + original_count_letters[i]
            assert(np.unique(random_letters[first:last]) == alphabet[i])
            first = last
    except AssertionError:
        return False
    return True

# %%
# This should run without raising exceptions
assert_generation(original_count_letters, alphabet, random_letters)
# Out:
# True

# %% [markdown]
# Shuffle random_letters order randomly

# %%
original_random_letters = random_letters.copy()
random.shuffle(random_letters)

# %% [markdown]
# How would you asset that the result is different from the original list? What would the assert_generation function's result be for the suffled version?

# %%
assert(original_random_letters != random_letters)

# %% [markdown]
# Now we will start playing with the map, filter and reduce functions. The idea is to count the number of times a letter of the alphabet occurs from the shuffled array of generated random letters.
#
# In the MapReduce programming model the Map maps input elements to (key value) pairs, then each key is assignmed to a specific Reduce job that will process all the elements sharing the same key and normally computing a single result.
#
# Inspired in this programming model we will build:
# - A **mapper** function that will output (key, value) pairs where key are the letters of the alphabet and value is a count that corresponds to that key.
# - A **split_by_key** function that will build a lists of lists in which each internal list corresponds to a specific key (letter)
# - A **reducer** function that will calculate the sum of partial counted values for each key

# %%
def mapper(letters):
    map_result = map(lambda x: (x, 1), letters)
    map_persist = list(map_result)
    return map_persist

# %%
for (i, (k, v)) in enumerate(mapper(random_letters)):
    if i >= 10:
        break
    print('i:', i, '(key, value):',(k, v))
# Out:
# i: 0 (key, value): ('s', 1)
# i: 1 (key, value): ('c', 1)
# i: 2 (key, value): ('v', 1)
# i: 3 (key, value): ('e', 1)
# i: 4 (key, value): ('g', 1)
# i: 5 (key, value): ('n', 1)
# i: 6 (key, value): ('s', 1)
# i: 7 (key, value): ('p', 1)
# i: 8 (key, value): ('z', 1)
# i: 9 (key, value): ('i', 1)

# %%
def split_by_key(alphabet, map_persist):
    """Try to solve it by using list comprehension"""
    return [[v for (k, v) in filter(lambda x: x[0] == letter, map_persist)] for letter in alphabet]

# %%
splitted_by_keys = split_by_key(alphabet, mapper(random_letters))

# %%
def reducer(splitted_by_keys):
    return [reduce(add, key_values) for key_values in splitted_by_keys]

# %%
calculated_count_letters = reducer(splitted_by_keys)

# %% [markdown]
# Assert in two different ways that the result you obtained is correct.

# %%
# Normal assertion
assert((original_count_letters != calculated_count_letters).sum() == 0)

# %%
# Numpy assertion
np.testing.assert_equal(original_count_letters, calculated_count_letters)

# %% [markdown]
# ### <font color='blue'>Exercise 2 – Science Fiction words</font>
# File 'pg31547.txt' contain the Science Fiction short story Youth by Isaac Asimov.
#
# Read the file and assign a list of its splitted lines to the variable story.

# %%
with open('pg31547.txt') as f:
    story = f.readlines()

# %% [markdown]
# Use list comprehension to build a list of words in the story.

# %%
words = [word for line in story for word in line.split()]

# %%
unique_words = np.unique(words)
count_words = {w: words.count(w) for w in unique_words}

# %%
count_words
# Out:
# {'eBooks,': 2,
#  'mold."': 1,
#  'muttered,': 2,
#  'alone,"': 1,
#  'Dad': 11,
#  'RIGHT': 1,
#  "'Come": 1,
#  'lad."': 2,
#  'tradition.': 1,
#  'XIV': 1,
#  'brood."': 1,
#  'each': 4,
#  'Industry': 1,
#  'height': 1,
#  'position': 2,
#  '"There\'ll': 1,
#  'Lunch': 1,
#  'Before': 1,
#  'money': 3,
#  'due': 1,
#  'Real': 1,
#  'appearance': 1,
#  'License': 8,
#  'especially,': 1,
#  'denser': 1,
#  'felt': 9,
#  'methodically': 1,
#  'Arcturian': 2,
#  'used': 5,
#  'laughed': 1,
#  'workmanship': 1,
#  'obtain': 3,
#  'best': 3,
#  'landed,': 1,
#  'species,': 1,
#  'build': 1,
#  'vessel.': 1,
#  'worlds,"': 1,
#  'ashes': 1,
#  'variety': 1,
#  'Did': 1,
#  'around.': 2,
#  'chose': 1,
#  'who': 10,
#  'circus."': 1,
#  'rimmed': 1,
#  'read,': 1,
#  'land."': 1,
#  'controls': 1,
#  'sure': 4,
#  'charger': 1,
#  'dry': 1,
#  'Business!': 1,
#  'cautious': 1,
#  'on,': 3,
#  'word': 2,
#  'critical': 1,
#  'violates': 1,
#  'refund.': 2,
#  'mastered': 1,
#  'inner': 1,
#  'annoyed.': 1,
#  'berries': 2,
#  '(any': 1,
#  'publicity': 1,
#  'repaired."': 1,
#  'early?': 1,
#  'right,': 3,
#  'peace': 1,
#  'ever': 4,
#  'agreement,': 6,
#  'adults,': 1,
#  'again.': 5,
#  '"Sir?"': 3,
#  'tried': 1,
#  'fodder.': 1,
#  'met': 2,
#  'fought': 1,
#  'within': 6,
#  'maintaining': 2,
#  'realized': 2,
#  'periods.': 1,
#  'tell."': 1,
#  '"One': 2,
#  'joke': 1,
#  '1.F.3.': 1,
#  '"Your': 1,
#  'interpreted': 2,
#  'recovered': 2,
#  'fault."': 1,
#  'theirs': 1,
#  '1.E.8': 2,
#  'quickly,': 3,
#  'model,': 1,
#  'penalty': 1,
#  'sick,': 1,
#  'same.': 1,
#  'research.': 1,
#  'wrong,': 1,
#  "We've": 2,
#  'cannot': 5,
#  'sidelong.': 1,
#  'drew': 2,
#  'years,': 1,
#  'unsupported': 1,
#  'refund': 6,
#  'home': 1,
#  'might': 11,
#  'check': 3,
#  'reconnaissance.': 1,
#  'fathers.': 1,
#  'deletions': 1,
#  'back': 11,
#  'CONSEQUENTIAL,': 1,
#  'different,': 1,
#  '50': 1,
#  '3': 3,
#  'need': 3,
#  '"Other': 1,
#  'take': 11,
#  'canvas."': 1,
#  'tawdry': 1,
#  'dead."': 3,
#  'zillions': 1,
#  '"need': 1,
#  'concerning': 2,
#  'hedge.': 1,
#  'house!': 1,
#  'mine.': 1,
#  'opportunity': 3,
#  'contributions': 1,
#  'now?"': 1,
#  'bar': 1,
#  "they'll": 2,
#  'else."': 1,
#  'Red!"': 1,
#  'general': 2,
#  'men': 1,
#  'properly': 1,
#  'animals.': 3,
#  'world;': 1,
#  'notice': 2,
#  'till': 3,
#  '_told_': 1,
#  'slope': 1,
#  '_not_': 1,
#  'Besides,': 3,
#  '1.C': 1,
#  'leaves,': 1,
#  'UNDER': 1,
#  'unaware': 1,
#  '3.': 1,
#  'such': 15,
#  'elaborate': 2,
#  'thunder,': 1,
#  'Ejectors': 1,
#  'losing': 1,
#  'there.': 4,
#  'times': 1,
#  'reversal': 1,
#  'green-covered': 1,
#  'print': 1,
#  '"Their': 1,
#  'DISCLAIMER': 1,
#  'bad.': 1,
#  'royalty': 1,
#  'burnt': 2,
#  '1.E.': 1,
#  "I've": 9,
#  'son."': 1,
#  'marked': 2,
#  "'Yes.'": 1,
#  'exactly': 3,
#  'doing?"': 1,
#  'name': 4,
#  'WARRANTY': 1,
#  'smiling': 1,
#  'watched': 2,
#  'DAMAGE.': 1,
#  'Slim,': 7,
#  'DISTRIBUTOR': 1,
#  'dewy': 1,
#  'will': 23,
#  'virus,': 1,
#  'despite': 3,
#  'systems,': 1,
#  'detected': 1,
#  'carelessly,': 2,
#  'us': 8,
#  'attached': 1,
#  'Doctor.': 1,
#  '_trying_': 1,
#  'do,"': 1,
#  'remember': 4,
#  'Dad.': 4,
#  'describe': 3,
#  'fees,': 1,
#  'remained': 3,
#  'secret?"': 2,
#  'half': 1,
#  'not.': 6,
#  'arise': 1,
#  '"Quiet!': 1,
#  'her.': 3,
#  'specific': 1,
#  'man': 1,
#  '"Defects,"': 1,
#  'WORK': 1,
#  'bite': 1,
#  'fiercely': 1,
#  'broadening': 1,
#  '"Then,': 1,
#  'void': 1,
#  'point.': 1,
#  'process."': 1,
#  'Merchant.': 1,
#  'instead': 1,
#  'before,': 2,
#  'electronically': 1,
#  'true,': 1,
#  'be."': 1,
#  'care': 3,
#  'closed.': 1,
#  'damages.': 1,
#  'animals,': 1,
#  'light': 1,
#  'sustained': 1,
#  'self-control.': 1,
#  'soil': 1,
#  'this,': 1,
#  'waved': 3,
#  'sorry,': 1,
#  'small.': 1,
#  'designed': 2,
#  'them.': 22,
#  '"Inhabited?"': 1,
#  'calculated': 1,
#  'say,': 1,
#  '"Two."': 1,
#  'wife.': 3,
#  'affected': 1,
#  'useful': 1,
#  '($1': 1,
#  'playing': 1,
#  'royalties.': 1,
#  'color': 1,
#  'smaller': 3,
#  'coarse': 1,
#  'thinks': 1,
#  '1.E.9.': 3,
#  'asleep.': 1,
#  'allow': 1,
#  'acted': 1,
#  'move': 2,
#  'much': 9,
#  'alternate': 1,
#  'prison.': 1,
#  'theories': 1,
#  '"No."': 1,
#  'softly,': 2,
#  'old': 8,
#  'whatsoever.': 2,
#  'to,': 8,
#  '(if': 1,
#  'rings': 1,
#  'high': 6,
#  'theirs."': 1,
#  'real': 6,
#  'your': 37,
#  'year.': 1,
#  'computers.': 1,
#  'good': 11,
#  '1.E.8.': 2,
#  'followed': 3,
#  'bounded': 1,
#  'carried': 1,
#  'sound': 1,
#  '"I\'ve': 5,
#  'know--I': 1,
#  'elders': 1,
#  '2010': 1,
#  'fault.': 1,
#  'quite."': 1,
#  'base': 1,
#  'tired,': 1,
#  'personal': 1,
#  'fees': 2,
#  'precise.': 1,
#  'specimens': 1,
#  'promised': 2,
#  'earnestly.': 1,
#  'caught,': 1,
#  'walked': 3,
#  'user,': 1,
#  'crash,': 1,
#  'sleep.': 1,
#  'request,': 1,
#  'dipped': 1,
#  'every': 1,
#  'realize': 1,
#  'eat,': 1,
#  'speak.': 1,
#  'chivvy': 1,
#  'States.': 4,
#  'Astronomer,': 6,
#  '"As': 1,
#  'synonymous': 1,
#  'over': 8,
#  'creek."': 1,
#  'Foundation."': 1,
#  'during': 2,
#  'dyes,': 1,
#  'Gutenberg-tm.': 1,
#  'out,"': 2,
#  'people-things': 1,
#  'approach': 2,
#  'directed': 1,
#  'intelligent.': 1,
#  'civilization.': 1,
#  'year': 1,
#  '(801)': 1,
#  'one.': 3,
#  'quarreling': 1,
#  'computers': 1,
#  'Hart,': 1,
#  'countries': 1,
#  'occur:': 1,
#  'yet': 4,
#  'lowered': 1,
#  'sending': 1,
#  'Seconds': 1,
#  'law--"': 1,
#  'Gregory': 1,
#  '"You': 14,
#  'wrote': 1,
#  "it's": 10,
#  'coincidences.': 1,
#  'While': 1,
#  'EXPRESS': 1,
#  'gross': 1,
#  'THE': 4,
#  'shotgun.': 1,
#  '_sounded_': 1,
#  'see,': 3,
#  'except': 4,
#  'grimaced': 1,
#  'Golly,': 1,
#  'ancient': 1,
#  'far': 2,
#  'looks': 2,
#  '"Information': 1,
#  'target-point,': 1,
#  'muttered': 1,
#  'performing,': 3,
#  '(does': 1,
#  'opened': 1,
#  'slightly.': 1,
#  'descending': 2,
#  'makes': 2,
#  'different.': 1,
#  'about.': 1,
#  '31547.txt': 1,
#  'out?"': 1,
#  'Back': 1,
#  'Earth,': 1,
#  'entirely': 4,
#  'LIMITED': 3,
#  'leave.': 1,
#  "we'll": 1,
#  'law': 1,
#  'returned': 1,
#  'overcome.': 1,
#  'Carbon': 1,
#  "Anything'll": 1,
#  'talking': 6,
#  'ingredients.': 1,
#  'now': 4,
#  'panting': 1,
#  '"It': 9,
#  'stop.': 1,
#  'home,': 1,
#  'tremendous': 2,
#  'whispered': 1,
#  'seat."': 1,
#  'Gradual': 1,
#  'dangerous,': 1,
#  'nonproprietary': 1,
#  'northern': 1,
#  'guest': 1,
#  'so?"': 1,
#  'Doctor."': 1,
#  'its': 19,
#  'exposed': 1,
#  '1.B.': 1,
#  'landing."': 1,
#  'punishment': 1,
#  'says.': 1,
#  'mean': 6,
#  'are,': 2,
#  'least,': 1,
#  'medium,': 2,
#  'WARRANTIES': 2,
#  'rarely': 1,
#  'began': 2,
#  'she': 5,
#  'sir."': 7,
#  'Look,': 1,
#  'promise': 1,
#  'queer': 1,
#  'agent': 1,
#  'past.': 1,
#  'acts': 1,
#  'leave': 1,
#  'saw': 7,
#  'lead': 1,
#  'circuses?"': 1,
#  'trader': 1,
#  'finger': 1,
#  '"Mother': 1,
#  'saying': 3,
#  'get': 14,
#  'said': 40,
#  'animals?"': 5,
#  'before': 15,
#  'another."': 1,
#  'nonchalantly': 1,
#  'clean': 1,
#  'SUCH': 1,
#  'control': 2,
#  'MERCHANTIBILITY': 1,
#  'development': 2,
#  "That's": 7,
#  'Beforethewars.': 4,
#  'waiting."': 1,
#  'easily-recognized': 1,
#  'stood': 2,
#  'additions': 1,
#  'adults.': 1,
#  'shook': 2,
#  '1.C.': 1,
#  '*****': 2,
#  'news': 1,
#  'landing?"': 1,
#  'therefore': 1,
#  'quiet': 1,
#  'not--"': 1,
#  '"Perhaps,"': 1,
#  '"Just': 3,
#  'longer': 2,
#  'Fewer': 1,
#  'joined': 1,
#  'higher': 1,
#  'word!': 1,
#  'branches': 1,
#  'BREACH': 2,
#  'youngsters?': 1,
#  'Smokes.': 2,
#  'hard': 2,
#  'distribute': 5,
#  'anywhere': 2,
#  'over!': 1,
#  'FULL': 2,
#  'person': 4,
#  'spirit': 1,
#  'representations': 1,
#  'victory,': 1,
#  "doesn't": 1,
#  'copied': 2,
#  'donations': 11,
#  'format': 4,
#  'loose': 2,
#  'holder.': 1,
#  '_he_': 1,
#  'youngsters.': 1,
#  'Ours': 2,
#  '"And': 10,
#  'possibly': 2,
#  'gall': 1,
#  'simply': 3,
#  'in.': 1,
#  'tones,': 1,
#  'proud': 2,
#  "We're": 1,
#  '"Come,': 1,
#  'think': 20,
#  'son.': 1,
#  'beginning': 1,
#  'THIS': 5,
#  'impertinent': 1,
#  'in': 183,
#  'eBooks': 3,
#  "They're": 4,
#  'ports.': 1,
#  'were.': 1,
#  'added': 1,
#  'Author:': 1,
#  'name--there': 1,
#  'second': 5,
#  'domain': 7,
#  'though,': 1,
#  'asked.': 1,
#  '-': 7,
#  'yours,': 1,
#  'problem.': 1,
#  'gentleness."': 1,
#  'kept': 4,
#  'line': 2,
#  'influential': 1,
#  'more.': 1,
#  'still': 8,
#  'concrete': 1,
#  'evolution': 1,
#  'Maybe': 3,
#  'Just': 1,
#  'scold': 1,
#  'to': 311,
#  'anything.': 1,
#  'PGLAF),': 1,
#  'canvas,': 1,
#  'desperately.': 1,
#  'Special': 1,
#  'absorption': 1,
#  'call': 5,
#  "Transcriber's": 1,
#  'OF': 10,
#  'For': 6,
#  'cowardy-cat."': 1,
#  'Aluminum?"': 1,
#  'artillery."': 1,
#  'see?': 1,
#  'arc.': 1,
#  'appears,': 1,
#  '"Right': 3,
#  'North': 1,
#  'Explorer,': 4,
#  'happens': 1,
#  'it,': 8,
#  '_our_': 1,
#  'seem': 1,
#  'coming': 4,
#  'post': 1,
#  'material': 1,
#  '_your_': 1,
#  'party': 1,
#  'stuff?"': 1,
#  'downloading,': 1,
#  'Earthly': 1,
#  'profit': 1,
#  'sleeps': 1,
#  'trademark,': 3,
#  'donate.': 1,
#  'official': 3,
#  "isn't.": 1,
#  'terms': 19,
#  'along': 3,
#  'Tell': 2,
#  'horrible.': 1,
#  'bit': 1,
#  'youth,': 2,
#  'right': 10,
#  'volunteer': 1,
#  'united': 1,
#  '"Horrible-looking': 1,
#  'or,': 1,
#  'Mind': 1,
#  'donation': 1,
#  'Now': 5,
#  'story.': 1,
#  'wants': 2,
#  '"Reason': 1,
#  'sense': 2,
#  'does': 2,
#  'hoarse,': 1,
#  '"Then?': 1,
#  'me."': 2,
#  'determine': 1,
#  'Melan': 1,
#  'follow': 2,
#  '"Is': 1,
#  'Blundell': 2,
#  'created': 2,
#  'hurt?"': 1,
#  'unmaneuverable': 1,
#  "Foundation's": 3,
#  'eagerly,': 1,
#  'that?"': 3,
#  'lad?"': 1,
#  '4,': 1,
#  '"Yes.': 1,
#  'halt.': 1,
#  'stored,': 1,
#  'scout-ship.': 1,
#  'use': 12,
#  'voice.': 2,
#  'them': 45,
#  '(c)': 1,
#  'trotted': 1,
#  'http://www.gutenberg.net': 1,
#  'pebbles': 1,
#  '"She': 1,
#  'offers': 1,
#  'accepting': 1,
#  'came,': 1,
#  'soupy': 1,
#  'field': 2,
#  'inside': 1,
#  'spasm,': 1,
#  'want,': 1,
#  '"A': 5,
#  'strap': 1,
#  'maintain': 2,
#  'final': 3,
#  '"Cowardy-cat.': 1,
#  'various': 1,
#  'faithfully,': 1,
#  'basic': 2,
#  'week.': 1,
#  'Gutenberg-tm': 53,
#  '"Really,': 1,
#  'demand': 1,
#  'window': 2,
#  'With': 2,
#  'thank': 1,
#  'consider': 2,
#  '_has_': 1,
#  'crawled': 1,
#  '"But': 4,
#  'awake.': 2,
#  'space-ships': 1,
#  'access': 10,
#  'implying?"': 1,
#  'infringement,': 1,
#  'cost': 2,
#  'just--"': 1,
#  'whipped': 1,
#  'scout-ship,': 1,
#  'chance."': 2,
#  'III': 1,
#  'noise': 2,
#  'deal': 1,
#  'tracks.': 1,
#  'already': 2,
#  'brightened': 1,
#  'rocket': 2,
#  'unpleasant': 1,
#  'least': 4,
#  'finally,': 2,
#  'argumentative.': 2,
#  "They'll": 1,
#  'occurrence': 1,
#  'caught': 3,
#  'poorer': 2,
#  'whopping': 1,
#  'City,': 1,
#  'worlds?"': 1,
#  'cost,': 1,
#  'my."': 1,
#  'convert': 1,
#  'particularly': 1,
#  'up,': 4,
#  'U.S.': 4,
#  "weren't": 3,
#  'further,"': 1,
#  'struggled': 2,
#  'frowned.': 2,
#  'hope,': 1,
#  'collision,': 1,
#  'sounding': 1,
#  'Not': 2,
#  'Chief': 1,
#  'equipment.': 2,
#  'bring': 5,
#  'scattered': 1,
#  'change': 5,
#  'circus.': 1,
#  'works.': 5,
#  'ate': 2,
#  'knows': 2,
#  'simpler': 1,
#  'day': 7,
#  'VII': 1,
#  'look,': 1,
#  'secret.': 5,
#  'received,': 1,
#  'stupid': 2,
#  'AND': 1,
#  'easy.': 1,
#  'Try': 1,
#  'work,': 7,
#  'where': 10,
#  'nothing.': 1,
#  'excuse': 2,
#  'colonization."': 1,
#  'Good': 1,
#  'earth': 1,
#  'atomic': 8,
#  'http://www.pglaf.org.': 1,
#  'nearest': 1,
#  'http://www.pgdp.net': 2,
#  'painfully': 1,
#  'nothing': 3,
#  'water': 1,
#  'disclaim': 1,
#  '[Last': 1,
#  'that?': 3,
#  'partly': 1,
#  'solvents.': 1,
#  '"Hello,': 1,
#  'comes,': 1,
#  'indemnify': 1,
#  'sight,': 1,
#  'discovered': 1,
#  'Astronomy': 1,
#  'temperature': 1,
#  '"What\'s': 4,
#  'story,': 1,
#  'disclaimers': 1,
#  'strong': 1,
#  'B.': 1,
#  'newsletter': 1,
#  'morning."': 1,
#  'charge': 6,
#  'near': 1,
#  "'AS-IS'": 1,
#  'challenge.': 1,
#  'back.': 1,
#  'unrestrained': 1,
#  'impossible': 3,
#  'solvent.': 1,
#  'I': 129,
#  'worry.': 1,
#  '"This': 1,
#  'THOSE': 1,
#  'cease': 1,
#  "that's": 5,
#  'form,': 1,
#  'determine?"': 1,
#  'appropriateness': 1,
#  '"Take': 1,
#  '"Watch': 1,
#  "wouldn't": 10,
#  'be.': 1,
#  'accept': 3,
#  'In': 5,
#  'slipped': 1,
#  'laws.': 1,
#  'making': 5,
#  'outdated': 1,
#  'regret': 1,
#  'phrase': 5,
#  'surprise': 1,
#  'window.': 3,
#  'LIABILITY,': 1,
#  'identification': 1,
#  'nearly': 2,
#  'inaccurate': 1,
#  'turn': 1,
#  'handled': 1,
#  '"Look,': 1,
#  'by': 31,
#  'tell': 16,
#  'wood.': 1,
#  'life': 2,
#  'alone': 2,
#  '"Who?': 1,
#  'talk': 4,
#  'grass': 4,
#  'black.': 2,
#  'queer,': 1,
#  'remaining': 2,
#  'hug': 1,
#  'gathered': 1,
#  'animal': 3,
#  'associated': 7,
#  'Or': 1,
#  'derive': 1,
#  'reluctantly.': 1,
#  'food.': 1,
#  'rough': 1,
#  '_holding_': 1,
#  'computer': 2,
#  'www.gutenberg.net': 2,
#  'outpost': 1,
#  'frowning.': 1,
#  'way': 6,
#  'interstellar': 2,
#  'worry."': 1,
#  'pressure.': 1,
#  'empty': 3,
#  'theory': 2,
#  'speak': 8,
#  'paper': 1,
#  '90': 2,
#  'modification,': 1,
#  'online': 4,
#  'wait': 2,
#  'freighter.': 1,
#  'limping': 1,
#  "we've": 1,
#  'question': 1,
#  'office': 2,
#  'intellectual': 2,
#  'stares': 1,
#  'too,': 1,
#  'joking.': 1,
#  'of.': 1,
#  'Such': 1,
#  'vaguely.': 1,
#  'distance': 2,
#  'engines.': 1,
#  'hydrogen': 1,
#  'visit:': 1,
#  'after': 11,
#  'pull': 1,
#  'uninhabitable': 1,
#  'Superficially,': 1,
#  'After': 1,
#  'spatter': 1,
#  'wash': 1,
#  'saying,': 2,
#  'grind': 1,
#  'colder': 1,
#  'always.': 1,
#  'Will': 1,
#  'swaying': 1,
#  '"If': 6,
#  'Explorer': 16,
#  'competition': 1,
#  'bombs,"': 1,
#  'mission': 3,
#  'lifted': 7,
#  'ten': 2,
#  'reflected': 1,
#  'revolting': 1,
#  'be': 80,
#  'cool': 1,
#  'Fine': 1,
#  'space-ship': 3,
#  'glories': 1,
#  'bowl': 1,
#  'pardon.': 1,
#  'requirements.': 1,
#  'appearing': 1,
#  '1.E.3.': 1,
#  'thing,': 2,
#  'EXCEPT': 1,
#  "ship's": 1,
#  'and': 275,
#  'Perhaps': 1,
#  'Yes!': 1,
#  'Redistributing': 1,
#  'ask': 9,
#  'getting': 5,
#  'yellowish': 1,
#  'true.': 3,
#  'PURPOSE.': 1,
#  '"There': 3,
#  '_only_': 1,
#  'nodded.': 1,
#  'someone': 1,
#  '"Acrobats?"': 1,
#  'guess."': 1,
#  'continent': 1,
#  'once': 5,
#  '4557': 1,
#  'swinging': 1,
#  'requirements,': 1,
#  'daring': 1,
#  'understand': 2,
#  '"No.': 2,
#  'somewhere.': 1,
#  'sell': 1,
#  'either': 1,
#  'eight': 1,
#  '"For': 3,
#  'society.': 1,
#  "case--it's": 1,
#  'performances': 1,
#  'quiet.': 1,
#  'aside': 1,
#  'huge': 2,
#  'metal': 1,
#  'comfortably': 1,
#  'circus': 8,
#  'One': 2,
#  'formed': 2,
#  'minutes': 1,
#  'basso': 1,
#  'power': 1,
#  'At': 5,
#  'armed."': 1,
#  'here': 10,
#  'built': 2,
#  'smiling.': 1,
#  'Copyright': 1,
#  'trade,': 2,
#  'originator': 1,
#  'economy."': 1,
#  'moved': 4,
#  'errand,': 1,
#  'around."': 1,
#  'another.': 1,
#  'normal': 2,
#  'editions,': 1,
#  'asteroid-dwellers."': 1,
#  'quarters.': 1,
#  'bars.': 2,
#  'pages': 1,
#  'raw."': 1,
#  'sauntered': 1,
#  'stowed': 1,
#  'raining.': 1,
#  'survivors.': 1,
#  'PG': 1,
#  'serve': 1,
#  'Together': 1,
#  'absorbed': 1,
#  'Yet': 1,
#  'established': 1,
#  'usual': 2,
#  'obvious.': 1,
#  '"Huh.': 1,
#  'subetherics': 1,
#  'extent': 1,
#  'nowhere,"': 1,
#  'quickly': 2,
#  'visi-plate.': 1,
#  'same': 2,
#  'spoken': 2,
#  'away': 12,
#  'thunderstorm.': 1,
#  'raw': 3,
#  'job."': 1,
#  'thrusting': 1,
#  'redistribute': 1,
#  'kids.': 1,
#  'old,': 1,
#  'first?"': 1,
#  'shall': 2,
#  'stellar': 4,
#  'PROVIDED': 1,
#  'written.': 1,
#  'feats': 1,
#  'eBooks.': 2,
#  'their': 35,
#  'there': 28,
#  'disclaimer': 2,
#  'lined': 1,
#  'Director': 1,
#  '(www.gutenberg.net),': 1,
#  'start': 4,
#  'ammonia': 1,
#  'energetically,': 1,
#  'hundreds': 1,
#  'Newby': 1,
#  '"Ever': 2,
#  'yet--perhaps': 1,
#  'anyway?': 1,
#  'living': 2,
#  'items': 1,
#  'current': 1,
#  'found': 14,
#  'linked': 1,
#  'other': 22,
#  'He': 82,
#  'valid': 1,
#  '"Sure.': 2,
#  'attack': 1,
#  'return?"': 1,
#  'Slim': 58,
#  'END': 1,
#  'hooked': 1,
#  'well,': 1,
#  "it'll": 2,
#  'with': 96,
#  'classes': 1,
#  'Redistribution': 1,
#  'calculate': 1,
#  'rules,': 1,
#  'caves?"': 1,
#  'searched': 1,
#  'interest': 2,
#  'creek': 1,
#  'long.': 2,
#  'unenforceability': 1,
#  'approached': 1,
#  'thunder.': 1,
#  'Certainly': 1,
#  'ratio': 1,
#  'moment,': 6,
#  'necessary': 2,
#  'islands--I': 1,
#  'kills': 1,
#  'hour,"': 1,
#  'sufficiently': 1,
#  'compliance.': 1,
#  'smile': 1,
#  'However,': 3,
#  'able': 2,
#  'entire': 1,
#  ...}

# %% [markdown]
# Achieve the same results by using a Counter object

# %%
count_words_alt = Counter(words)

# %%
# This assertion should hold
assert(count_words == count_words_alt)
